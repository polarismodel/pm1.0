# %% [markdown]
# # Polaris LLM (PM1) Training — Google Colab
# This notebook trains the Polaris LLM (PM1) using your repo code and saves outputs to Google Drive.

# %%
# 1. Connect to Google Drive (for saving outputs)
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Clone your repo (or upload code manually)
# !git clone https://github.com/polarismodel/pm1.0.git
# %cd pm1.0

# %%
# 3. Install dependencies
# !pip install -r requirements.txt

# %%
# 4. Run training script
# !python training/train_gpt2.py

# %%
# 5. Copy trained model to Google Drive for download
# !cp -r models/polaris-pm1 /content/drive/MyDrive/Polaris_PM1_output

# %% [markdown]
# ## Notes
# - You can monitor training progress in the output cells.
# - The trained model will be available in your Google Drive under `Polaris_PM1_output`.
# - If you want to use a subset of the data, edit the training script or add filtering steps here.
